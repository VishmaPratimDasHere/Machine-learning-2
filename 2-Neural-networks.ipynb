# %%
# Tensorflow and helper libraries import

import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import the fashion_mnist dataset
fashion_mnist=tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Let's see the first item. Looks like a shoe.
plt.figure()
plt.imshow(train_images[0], cmap=plt.cm.binary)

# %%
# TO TEST, UNCOMMENT THIS CELL:
# plt.figure(figsize=(1,1))
# plt.imshow(train_images[0], cmap=plt.cm.binary)

# %%
#
train_images = train_images/255.0 # Normalise for calculation simplicity
plt.figure(figsize=(10.5,10.4))
for x in range(25):
  plt.subplot(7,4,x+1) # 0th picture will have 1 index, 1st picture will have 2 index, and so on
  plt.xticks([])
  plt.yticks([])
  plt.imshow(train_images[x], cmap=plt.cm.binary)
  plt.xlabel(class_names[train_labels[x]])

# %%
# Checking the shape for future flattening
np.array(train_images[0]).shape
# Out:
# (28, 28)

# %%
# Create the neural network
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='sigmoid'),
    tf.keras.layers.Dense(10)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Fit the training data
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5434 - accuracy: 0.8125
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3913 - accuracy: 0.8597
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3550 - accuracy: 0.8710
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3282 - accuracy: 0.8810
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3119 - accuracy: 0.8860
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2953 - accuracy: 0.8909
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2815 - accuracy: 0.8968
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2712 - accuracy: 0.9000
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2611 - accuracy: 0.9038
# Epoch 10/10
# ...

# %%
# Test the model
model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.4173 - accuracy: 0.8587 - 635ms/epoch - 2ms/step
# [0.4173210561275482, 0.8586999773979187]
